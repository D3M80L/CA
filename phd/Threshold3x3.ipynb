# %%
import catools as catools

# %%
lut = [0.0094220788056185,0.0089778109738877,0.0506542601172838,0.0148475414685278,0.3582985356212308,0.0000000000000000,0.4368476624947731,0.0349355409111639,0.1542649789427312,0.0564312532604916,0.7700410565079709,0.3954581037799654,0.4888848643107001,0.9479710256801075,0.9995138259991005,0.0413349007990867,0.5206026658066896,0.0000000000000000,0.8629755604608232,0.5770411756999720,0.9287420382591846,0.8481530205452407,0.9973319317629893,0.0108969658195211,0.7495690598626537,0.9811385956510490,0.9915991262973569,0.9485404068339514,1.0000000000000000,0.7718279184631588]

# %%
threshold=0.05

# %% [markdown]
# The configuration below requires 28 iterations to get all cells equal to 1 and 4 iterations to reach the threshold value.

# %%
configuration = catools.parse_2d_configuration("1;1;1;1;0;0;1;0;1", 3, 3)
catools.animate_iterate_configuration_to(configuration, lut, 30, title=catools.title_notify_when_threshold_reached(threshold))
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img8086ec4a005044f7b4742b0df45aea39">
#   <div class="anim-controls">
#     <input id="_anim_slider8086ec4a005044f7b4742b0df45aea39" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim8086ec4a005044f7b4742b0df45aea39.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim8086ec4a005044f7b4742b0df45aea39.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim8086ec4a005044f7b4742b0df45aea39.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim8086ec4a005044f7b4742b0df45aea39.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim8086ec4a005044f7b4742b0df45aea39.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim8086ec4a005044f7b4742b0df45aea39.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim8086ec4a005044f7b4742b0df45aea39.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim8086ec4a005044f7b4742b0df45aea39.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim8086ec4a005044f7b4742b0df45aea39.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim8086ec4a005044f7b4742b0df45aea39.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select8086ec4a005044f7b4742b0df45aea39" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_8086ec4a005044f7b4742b0df45aea39"
#              >
#       <label for="_anim_radio1_8086ec4a005044f7b4742b0df45aea39">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_8086ec4a005044f7b4742b0df45aea39"
#              checked>
#       <label for="_anim_radio2_8086ec4a005044f7b4742b0df45aea39">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_8086ec4a005044f7b4742b0df45aea39"
#              >
#       <label for="_anim_radio3_8086ec4a005044f7b4742b0df45aea39">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img8086ec4a005044f7b4742b0df45aea39";
#     var slider_id = "_anim_slider8086ec4a005044f7b4742b0df45aea39";
#     var loop_select_id = "_anim_loop_select8086ec4a005044f7b4742b0df45aea39";
#     var frames = new Array(30);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjEsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+j8jraAAAQJUlEQVR4nO3ce6zXdf3A8ddR8cDhesZRCxXCYygJ\
# QqmdNS1L+wM2G9gmWrJOWKfVPJS1kkQZ/aE5cLSWViuykdBFinTQmsG6GLVGw00IV2BF/qYD5KZw\
# 5gnQ8/790Y8zz+FwzvdwoC8vfo/HdrZzzvvzOd/X5/M+O0/OOV9OTSmlBAAkc1a1BwCAEyFgAKQk\
# YACkJGAApCRgAKQkYACkJGAApCRgAKQkYACkJGAApCRgAKQkYACkJGAApCRgAKQkYACkJGAApCRg\
# AKQkYACkJGCc1q644or43e9+V+0xTpl77rknvv71r1d1hne/+93x3HPPVXWGM4k9/S8qdBo3blxZ\
# t25dv8/bu3dvmTlzZqmrqytjx44tP/zhD0/BdCd/hh//+Mfl8ssvL3V1deWSSy4pv//97ytaGzp0\
# aJeXs846q7S2tp6S6zoV+nOv+j

# %% [markdown]
# The configuration below requires 32 iterations to get all cells equal to 1 and 8 to reach the threshold.

# %%
configuration = catools.parse_2d_configuration("1;1;0;1;1;0;0;1;0", 3, 3)
catools.animate_iterate_configuration_to(configuration, lut, 35, title=catools.title_notify_when_threshold_reached(threshold))
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgf34e1e2a003d4e449f3c3e576d840ba6">
#   <div class="anim-controls">
#     <input id="_anim_sliderf34e1e2a003d4e449f3c3e576d840ba6" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animf34e1e2a003d4e449f3c3e576d840ba6.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animf34e1e2a003d4e449f3c3e576d840ba6.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animf34e1e2a003d4e449f3c3e576d840ba6.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animf34e1e2a003d4e449f3c3e576d840ba6.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animf34e1e2a003d4e449f3c3e576d840ba6.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animf34e1e2a003d4e449f3c3e576d840ba6.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animf34e1e2a003d4e449f3c3e576d840ba6.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animf34e1e2a003d4e449f3c3e576d840ba6.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animf34e1e2a003d4e449f3c3e576d840ba6.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animf34e1e2a003d4e449f3c3e576d840ba6.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectf34e1e2a003d4e449f3c3e576d840ba6" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_f34e1e2a003d4e449f3c3e576d840ba6"
#              >
#       <label for="_anim_radio1_f34e1e2a003d4e449f3c3e576d840ba6">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_f34e1e2a003d4e449f3c3e576d840ba6"
#              checked>
#       <label for="_anim_radio2_f34e1e2a003d4e449f3c3e576d840ba6">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_f34e1e2a003d4e449f3c3e576d840ba6"
#              >
#       <label for="_anim_radio3_f34e1e2a003d4e449f3c3e576d840ba6">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgf34e1e2a003d4e449f3c3e576d840ba6";
#     var slider_id = "_anim_sliderf34e1e2a003d4e449f3c3e576d840ba6";
#     var loop_select_id = "_anim_loop_selectf34e1e2a003d4e449f3c3e576d840ba6";
#     var frames = new Array(35);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjEsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+j8jraAAAPwElEQVR4nO3cbWyWZ9nA8aOPY4VSXprWTdlG3Zhs\
# OBi4MRuDOt38AMkMncnYdCTItIlG0Gl0ODaCHzYXWDDGMc1EzeLwZVPcAsZMiC8RE4MPJIAsClPR\
# ZAsgL92gWTfYOJ8PSkOhtHdp2d2D5/dLmtCe19X7uK6z6b8vd6kppZQAgGT+p9oDAMDZEDAAUhIw\
# AFISMABSEjAAUhIwAFISMABSEjAAUhIwAFISMABSEjAAUhIwAFISMABSEjAAUhIwAFISMABSEjAA\
# UhIwAFISMIa0a665Jn73u99Ve4xz5t57741vfOMbVZ3hPe95Tzz33HNVneF8Yk/fRIUuzc3NZcOG\
# Df0+7+DBg6W1tbXU1dWV8ePHlx/+8IfnYLrBneHGG28stbW1ZeTIkWXkyJFl4sSJFa2d8OMf/7hc\
# ffXVpa6urlxxxRXl97///aBf07

# %% [markdown]
# The below configuration requires 343 iterations to get all cells equal to 0 and 8 to reach the threshold.
# Animation limited to 35 due to size limitations.

# %%
configuration = catools.parse_2d_configuration("0;0;1;0;0;1;1;0;1", 3, 3)
catools.animate_iterate_configuration_to(configuration, lut, 35, title=catools.title_notify_when_threshold_reached(threshold))
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgc99bd0ad3b364f659e2e4f913ed8b595">
#   <div class="anim-controls">
#     <input id="_anim_sliderc99bd0ad3b364f659e2e4f913ed8b595" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animc99bd0ad3b364f659e2e4f913ed8b595.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animc99bd0ad3b364f659e2e4f913ed8b595.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animc99bd0ad3b364f659e2e4f913ed8b595.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animc99bd0ad3b364f659e2e4f913ed8b595.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animc99bd0ad3b364f659e2e4f913ed8b595.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animc99bd0ad3b364f659e2e4f913ed8b595.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animc99bd0ad3b364f659e2e4f913ed8b595.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animc99bd0ad3b364f659e2e4f913ed8b595.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animc99bd0ad3b364f659e2e4f913ed8b595.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animc99bd0ad3b364f659e2e4f913ed8b595.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectc99bd0ad3b364f659e2e4f913ed8b595" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_c99bd0ad3b364f659e2e4f913ed8b595"
#              >
#       <label for="_anim_radio1_c99bd0ad3b364f659e2e4f913ed8b595">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_c99bd0ad3b364f659e2e4f913ed8b595"
#              checked>
#       <label for="_anim_radio2_c99bd0ad3b364f659e2e4f913ed8b595">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_c99bd0ad3b364f659e2e4f913ed8b595"
#              >
#       <label for="_anim_radio3_c99bd0ad3b364f659e2e4f913ed8b595">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgc99bd0ad3b364f659e2e4f913ed8b595";
#     var slider_id = "_anim_sliderc99bd0ad3b364f659e2e4f913ed8b595";
#     var loop_select_id = "_anim_loop_selectc99bd0ad3b364f659e2e4f913ed8b595";
#     var frames = new Array(35);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjEsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+j8jraAAAPeElEQVR4nO3cbWyVd93A8d+5NyiU8pR2c2GOOqtM\
# HKz4gH2x+LT5AnRKp2FTR4JsNjEBdIs6HBviC3Vhk8U47hklGuLwYRh0AWM28GGJvsFoAsiiMJX5\
# YuFhsG5Q6c0g/O8X972GQmnPobDTH/l8kiZr/9fF+V3Xv+HLOT1dpZRSAgCS+a96DwAA50PAAEhJ\
# wABIScAASEnAAEhJwABIScAASEnAAEhJwABIScAASEnAAEhJwABIScAASEnAAEhJwABIScAASEnA\
# AEhJwABIScAY0a6//vp45pln6j3GRXPffffFt7/97brO8J73vCeeffbZus5wKbGnr6NCn9bW1rJ1\
# 69aazzt8+HDp7OwsjY2NZerUqeXHP/7xRZju4sywZ8+e0tDQUO64446a1qpZH6lquVdDHTuc9YMH\
# D5YpU6aUY8eOXdRreP/7318aGh

# %% [markdown]
# The configuration below requires 341 iterations to get all cells equal to 0 and 6 to reach the threshold. Animation limited to 35 due to size limitations.

# %%
configuration = catools.parse_2d_configuration("0;0;1;1;0;0;1;1;0", 3, 3)
catools.animate_iterate_configuration_to(configuration, lut, 35, title=catools.title_notify_when_threshold_reached(threshold))
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img30b0a936ac69427394e17c1d77b0a4c1">
#   <div class="anim-controls">
#     <input id="_anim_slider30b0a936ac69427394e17c1d77b0a4c1" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim30b0a936ac69427394e17c1d77b0a4c1.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim30b0a936ac69427394e17c1d77b0a4c1.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim30b0a936ac69427394e17c1d77b0a4c1.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim30b0a936ac69427394e17c1d77b0a4c1.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim30b0a936ac69427394e17c1d77b0a4c1.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim30b0a936ac69427394e17c1d77b0a4c1.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim30b0a936ac69427394e17c1d77b0a4c1.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim30b0a936ac69427394e17c1d77b0a4c1.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim30b0a936ac69427394e17c1d77b0a4c1.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim30b0a936ac69427394e17c1d77b0a4c1.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select30b0a936ac69427394e17c1d77b0a4c1" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_30b0a936ac69427394e17c1d77b0a4c1"
#              >
#       <label for="_anim_radio1_30b0a936ac69427394e17c1d77b0a4c1">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_30b0a936ac69427394e17c1d77b0a4c1"
#              checked>
#       <label for="_anim_radio2_30b0a936ac69427394e17c1d77b0a4c1">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_30b0a936ac69427394e17c1d77b0a4c1"
#              >
#       <label for="_anim_radio3_30b0a936ac69427394e17c1d77b0a4c1">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img30b0a936ac69427394e17c1d77b0a4c1";
#     var slider_id = "_anim_slider30b0a936ac69427394e17c1d77b0a4c1";
#     var loop_select_id = "_anim_loop_select30b0a936ac69427394e17c1d77b0a4c1";
#     var frames = new Array(35);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjEsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+j8jraAAAPeUlEQVR4nO3cbWyVd93A8V/vDQqlPKV1LsxRZ5WJ\
# gxXZsC+IT5svQKd0GjZ1JMhmExNAt6jDsSG+UBc2WYxDjRINcfgwDLqAMRv4sETfYEYCyKIwlfli\
# 4WGwblBXGYT//eK+11Ao7TkUdvojn0/ShPZ/XZzfdf0JX87pKXWllBIAkMz/1HoAADgfAgZASgIG\
# QEoCBkBKAgZASgIGQEoCBkBKAgZASgIGQEoCBkBKAgZASgIGQEoCBkBKAgZASgIGQEoCBkBKAgZA\
# SgIGQEoCxrB23XXXxdNPP13rMS6a++67L7797W/XdIb3vOc98eyzz9Z0hkuJPX0DFXq1tLSUrVu3\
# Vn3ekSNHSkdHR2loaCiTJ08uP/3pTy/CdBdnhr1795b6+vpyxx13VLVWyfpwVc29GuzYoawfOnSo\
# TJo0qbz66qsX9Rre//73l/r6+j
